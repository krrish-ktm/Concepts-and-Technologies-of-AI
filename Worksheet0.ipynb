# %% [markdown]
# #Q.no.7 Create empty lists for temperature classifiacations. Based on data - Answer all the questions. convert temperatures from celsius to Fahrenheit Analyze temperature patterns by time of day.

# %%
temperature= [8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5, 16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3, 13.4, 8.1,
17.9, 14.2, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7, 7.8, 17.5, 13.6, 8.7,
17.1, 13.8, 9.2, 18.1, 13.9, 8.3, 16.4, 12.7, 8.9, 18.2, 13.1, 7.8,
16.6, 12.5]
cold_temperature=[]
mild_temperature=[]
comfortable_temperature=[]
for temp in temperature:
    if temp<10:
        cold_temperature.append(temp)
    elif 10<=temp>15:
        mild_temperature.append(temp)
    elif 15<=temp>20:
        comfortable_temperature.append(temp)
print("cold_temperature:",cold_temperature)
print("mild_temperature:",mild_temperature)
print("comfortable_temperature_temperature:",comfortable_temperature)
temperatures_fahrenheit = []
for temp in temperature:
    fahrenheit = (temp * 9/5) + 32
    temperatures_fahrenheit.append(fahrenheit)
print("Temperatures in Fahrenheit:", temperatures_fahrenheit)
night_temps = []
evening_temps = []
day_temps = []
for i in range(0, len(temperature), 3):
    night_temps.append(temperature[i])
    evening_temps.append(temperature[i + 1])
    day_temps.append(temperature[i + 2])

average_day_temp = sum(day_temps) / len(day_temps)

print("Average day-time temperature:", average_day_temp)
import matplotlib.pyplot as plt

plt.plot(day_temps, marker='o', color='r', label='Day Temperature')
plt.title("Day vs Temperature")
plt.xlabel("Days")
plt.ylabel("Temperature (°C)")
plt.legend()
plt.show()
# Out:
# cold_temperature: [8.2, 7.9, 9.0, 8.5, 7.7, 8.4, 9.5, 8.1, 7.6, 8.0, 7.8, 8.7, 9.2, 8.3, 8.9, 7.8]
# mild_temperature: [17.4, 18.0, 17.8, 16.5, 17.2, 16.7, 18.3, 17.9, 17.0, 16.8, 17.5, 17.1, 18.1, 16.4, 18.2, 16.6]
# comfortable_temperature_temperature: []
# Temperatures in Fahrenheit: [46.76, 63.32, 57.379999999999995, 46.22, 64.4, 56.3, 48.2, 64.04, 55.4, 47.3, 61.7, 55.22, 45.86, 62.959999999999994, 55.94, 47.120000000000005, 62.059999999999995, 57.2, 49.1, 64.94, 56.120000000000005, 46.58, 64.22, 57.56, 45.68, 62.6, 55.04, 46.4, 62.24, 56.66, 46.04, 63.5, 56.48, 47.66, 62.78, 56.84, 48.56, 64.58, 57.02, 46.94, 61.519999999999996, 54.86, 48.02, 64.75999999999999, 55.58, 46.04, 61.88, 54.5]
# Average day-time temperature: 13.40625

# %% [markdown]
# #Q.no.8
# #Task 1 - Sum of Nested Lists:

# %%
def sum_nested_list(nested_list):

    total = 0
    for item in nested_list:
        if isinstance(item, list):
            total += sum_nested_list(item)
        else:
            total += item
    return total

# test the sample lisdt
nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
result = sum_nested_list(nested_list)
print("The total sum of all numbers in the nested list is:", result)
# Out:
# The total sum of all numbers in the nested list is: 36

# %% [markdown]
# #Task 2 - Generate All Permutations of a String:

# %%
def generate_permutations(s):
    def backtrack(path, used, permutations):
        if len(path) == len(s):
            permutations.append(''.join(path))
            return
        for i in range(len(s)):

            if used[i] or (i > 0 and s[i] == s[i - 1] and not used[i - 1]):
                continue
            used[i] = True
            path.append(s[i])
            backtrack(path, used, permutations)
            path.pop()
            used[i] = False

    permutations = []
    sorted_chars = sorted(s)
    backtrack([], [False] * len(s), permutations)
    return permutations
# Teste the function with the example strings
print(generate_permutations("abc"))
print(generate_permutations("aab"))
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
# ['aab', 'aba', 'baa']

# %% [markdown]
# #Task 3 - Directory Size Calculation:

# %%
def calculate_directory_size(directory):
    total_size = 0
    for key, value in directory.items():
        if isinstance(value, dict):
            total_size += calculate_directory_size(value)
        else:
            total_size += value
    return total_size
# Testinf the function with a sample directory structure
sample_directory = {
    "file1.txt": 700,
    "file2.txt": 1000,
    "subdir1": {
        "file3.txt": 500,
        "subdir2": {
            "file4.txt": 900,
            "file5.txt": 300,
        },
    },
    "file6.txt": 150,
}

result = calculate_directory_size(sample_directory)
print("The total size of the directory is:", result, "KB")
# Out:
# The total size of the directory is: 3550 KB

# %% [markdown]
# #Task 1 - Coin Change Problem:

# %%
def min_coins(coins, amount):

    # Initialize the DP table with a large value (amount + 1, which is effectively infinity for this problem)
    dp = [float('inf')] * (amount + 1)
    dp[0] = 0

    for coin in coins:
        for x in range(coin, amount + 1):
            dp[x] = min(dp[x], dp[x - coin] + 1)

    return dp[amount] if dp[amount] != float('inf') else -1

# Test the function with coins = [1, 2, 5] and amount = 11
coins = [1, 2, 5]
amount = 11
result = min_coins(coins, amount)
print(f"The minimum number of coins needed to make {amount} is: {result}")
# Out:
# The minimum number of coins needed to make 11 is: 3

# %% [markdown]
# #Task 2 - Longest Common Subsequence (LCS):

# %%
def longest_common_subsequence(s1, s2):
    dp = [[0] * (len(s2) + 1) for _ in range(len(s1) + 1)]

    for i in range(1, len(s1) + 1):
        for j in range(1, len(s2) + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

    return dp[len(s1)][len(s2)]

# Testing the function with example strings
s1 = "abcde"
s2 = "ace"
result = longest_common_subsequence(s1, s2)
print(f"The length of the LCS between '{s1}' and '{s2}' is: {result}")

print(f"The minimum number of coins needed to make {amount} is: {result}")
# Out:
# The length of the LCS between 'abcde' and 'ace' is: 3
# The minimum number of coins needed to make 11 is: 3

# %% [markdown]
# #Task 3 - 0/1 Knapsack Problem:

# %%
def knapsack(weights, values, capacity):
    n = len(weights)

    dp = [[0] * (capacity + 1) for _ in range(n + 1)]

    for i in range(1, n + 1):
        for w in range(1, capacity + 1):
            if weights[i - 1] <= w:
                # Maximize value: either include or exclude the current item
                dp[i][w] = max(dp[i - 1][w], dp[i - 1][w - weights[i - 1]] + values[i - 1])
            else:
                dp[i][w] = dp[i - 1][w]

    # The value at dp[n][capacity] is the maximum value achievable
    return dp[n][capacity]

# Test the function with example data
weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7
result = knapsack(weights, values, capacity)
print(f"The maximum value achievable with capacity {capacity} is: {result}")
# Out:
# The maximum value achievable with capacity 7 is: 9
